# %%
import matplotlib.pyplot as plt
import numpy as np


# Set up the plot
plt.figure(figsize=(12, 4), dpi=300)

# Add labels
plt.xlabel('Coordenada de reacción', fontsize=18)
plt.ylabel(' Energía (eV)',fontsize=18)

# Set ranges
plt.xlim(-0.2, 2.5)
plt.ylim(-1.5, 8.2)

# O2 ox
x_o2 = [0.0, 1.5, 2.0]  # Reaction states
y_o2 = [0.0, 2.18, 2.88]  #Energy of the states (in eV)

# V2O5 ox
x_v2o5 = [0.0, 1.0, 2.0]  # Reaction states
y_v2o5 = [0.0, 3.06, 5.93] #Energy of the states (in eV)

# Horizontal reference line at y=0 
plt.axhline(0, color='black', linewidth=1.5, linestyle='--')
plt.hlines(0.0, -0.3, 0.3, colors='black', linewidth=2.5)
plt.annotate('C$_{92}$+*O$_{2}$', (-0.05, -0.7), fontsize=18)
plt.annotate('V$_{24}$O$_{60}$/C$_{92}$', (-0.1, 0.5), fontsize=18, color='blue')

# Lines for O2
plt.annotate("", xytext=(0.3, 0.0), xy=(1.0, 2.18), arrowprops=dict(arrowstyle="->", color='black', lw=3))
plt.annotate('2.2 eV', (0.8, 0.75), fontsize=16)
plt.hlines(2.18, 1.0, 1.5, colors='black', linewidth=2.5)
plt.annotate('C$_{92}$O$_{2}$', (1.2, 1.5), fontsize=18)
plt.annotate("", xytext=(1.5, 2.18), xy=(1.8, 2.88), arrowprops=dict(arrowstyle="->", color='black', lw=3))
plt.annotate('0.7 eV', (1.6, 1.8), fontsize=16)
plt.hlines(2.88, 1.8, 2.5, colors='black', linewidth=2.5)
plt.annotate('C$_{91}$+*CO$_{2}$', (2.0, 2.2), fontsize=18)

# Lines for V2O5
plt.annotate("", xy=(0.6, 3.06), xytext=(0.3, 0.0), arrowprops=dict(arrowstyle="->", color='blue', lw=3))
plt.annotate('3.1 eV', (0.3, 2.3), fontsize=16, color='blue')
plt.hlines(3.06, 0.6, 1.2, colors='blue', linewidth=2.5)
plt.annotate('V$_{24}$O$_{59}$/C$_{92}$O$_{1}$', (0.7, 3.5), fontsize=18, color='blue')
plt.annotate("", xy=(1.8, 5.93), xytext=(1.2, 3.06), arrowprops=dict(arrowstyle="->", color='blue', lw=3))
plt.annotate('2.9 eV', (1.37, 5), fontsize=16, color='blue')
plt.hlines(5.93, 1.8, 2.5, colors='blue', linewidth=2.5)
plt.annotate('V$_{24}$O$_{58}$/C$_{91}$+*CO$_{2}$', (1.85, 6.2), fontsize=18, color='blue')

# Arrow for final states difference
plt.annotate("", xy=(2.3, 2.88), xytext=(2.3, 5.93), arrowprops=dict(arrowstyle="<->", color='red', lw=3))
plt.annotate('3.04 eV', (2.0, 4.4), fontsize=16, color='red')

# Adjust ticks and other formatting
plt.xticks([])
plt.yticks([0, 2, 4, 6])
plt.gca().yaxis.tick_right()
plt.gca().tick_params(axis='y', labelsize=16) 
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['left'].set_linewidth(2)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# Set up the plot
plt.figure(figsize=(8, 6), dpi=300)

# Add labels
plt.xlabel('Coordenada z', fontsize=18)
plt.ylabel('Potencial (V vs Li/Li$^{+}$)',fontsize=18)

# Set ranges
plt.xlim(0.0, 1.9)
plt.ylim(0.5, 3.9)

# Potentials
z_coor = [0.0, 1.5, 2.0]   # Reaction states
V_int = [0.57, 2.79, 3.23]  # Intercalation potential(in V)


# Lines for Li in CNT/V2O5
plt.hlines(0.57, 0.0, 0.5, colors='blue', linewidth=2.5)
plt.annotate('0.57 V', (0.15, 0.35), fontsize=16)
plt.annotate('Li en CNT', (0.1, 0.7), fontsize=16)

plt.plot([0.5, 0.7], [0.57, 2.79], color='black', linewidth=1.5, linestyle='--')

plt.hlines(2.79, 0.7, 1.2, colors='blue', linewidth=2.5)
plt.annotate('2.79 V', (0.85, 2.5), fontsize=16)
plt.annotate('Li en Interfaz', (0.75, 2.9), fontsize=16)

plt.plot([1.2, 1.4], [2.79, 3.23], color='black', linewidth=1.5, linestyle='--')

plt.hlines(3.23, 1.4, 1.9, colors='blue', linewidth=2.5)
plt.annotate('3.23 V', (1.55, 2.95), fontsize=16)
plt.annotate('Li en V$_{2}$O$_{5}$', (1.5, 3.35), fontsize=16)


# Adjust ticks and other formatting
plt.xticks([])
plt.yticks([0, 1, 2, 3], fontsize=16)
#plt.gca().yaxis.tick_right()
#plt.gca().tick_params(axis='y', labelsize=16) 
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['left'].set_linewidth(2)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the plot
plt.figure(figsize=(8, 6), dpi=300)

# Add labels with thicker font weight
plt.xlabel('Coordenada z', fontsize=22, fontweight='bold')
plt.ylabel('Potencial (V vs Li/Li$^{+}$)', fontsize=22, fontweight='bold')

# Set ranges
plt.xlim(0.0, 1.9)
plt.ylim(0.5, 3.9)

# Potentials
z_coor = [0.0, 1.5, 2.0]   # Reaction states
V_int = [0.57, 2.79, 3.23]  # Intercalation potential (in V)

# Lines for Li in CNT/V2O5
plt.hlines(0.57, 0.0, 0.5, colors='blue', linewidth=4)  # Aumentar el grosor de la línea
plt.annotate('0.57 V', (0.15, 0.35), fontsize=20, fontweight='bold')  # Texto en negrita
plt.annotate('Li en CNT', (0.1, 0.7), fontsize=18, fontweight='bold')  # Texto en negrita

plt.plot([0.5, 0.7], [0.57, 2.79], color='black', linewidth=3, linestyle='--')  # Aumentar el grosor de la línea

plt.hlines(2.79, 0.7, 1.2, colors='blue', linewidth=4)  # Aumentar el grosor de la línea
plt.annotate('2.79 V', (0.85, 2.5), fontsize=20, fontweight='bold')  # Texto en negrita
plt.annotate('Li en Interfaz', (0.7, 2.9), fontsize=18, fontweight='bold')  # Texto en negrita

plt.plot([1.2, 1.4], [2.79, 3.23], color='black', linewidth=3, linestyle='--')  # Aumentar el grosor de la línea

plt.hlines(3.23, 1.4, 1.9, colors='blue', linewidth=4)  # Aumentar el grosor de la línea
plt.annotate(r'3.23 V', (1.55, 2.95), fontsize=20, fontweight='bold')  # Texto en negrita
plt.annotate(r'Li en $\mathbf{V}_{2}\mathbf{O}_{5}$', (1.5, 3.35), fontsize=18, fontweight='bold')  # Subíndices en negrita

# Adjust ticks and other formatting
plt.xticks([])
plt.yticks([0, 1, 2, 3], fontsize=18, fontweight='bold')  # Hacer los ticks más gruesos

# Aumentar el grosor de los bordes de la gráfica
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['left'].set_linewidth(2)

# Display the plot
plt.tight_layout()
plt.show()
